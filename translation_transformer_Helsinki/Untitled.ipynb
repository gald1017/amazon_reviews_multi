# %%
import pandas as pd
import torch

# %%
torch.load('amz_train_es_to_en_Translation_Helsinki.pkl')
# Out:
# ['Nothing good went to me ka screen in less than 8 months and I have received no response from the manufacturer',
#  'Horrible, we had to buy another because neither we who know English nor a computer, after an hour was able to install it',
#  "They force you to buy two units and you get only one and there's no way to claim, a real scam, don't buy!!",
#  'I do not go into disqualifying the seller, I can only say that after two months of waiting.... I still did not have the product and I had to contact Amazon to claim its refund. Amazon a 10. It takes care of the problem, but I and disbursed my money and in two months I get it back TOTAL time loss. No words. And you decide',
#  "He's late and he's got the wrong size.",
#  'It never came to me and the salesman never contacted me despite trying twice.',
#  'The umbrella is of very poor quality, given the sensation that will break when you open it. It is very crappy.',
# ...
